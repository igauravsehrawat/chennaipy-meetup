# %% [markdown]
# ##1. From presentation prespective

# %%
###Use Images

# %%
###Use embedded videos

# %%
###Use graphs and charts

# %%
int?

# %%
from IPython.display import Image

# %%
image_object = Image(url='https://www.python.org/static/community_logos/python-logo-master-v3-TM.png')

# %%
image_object
# Out:
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png"/>

# %%
from IPython.display import FileLink, FileLinks
FileLinks('.')
# Out:
# ./
#   ipython-for development.ipynb
#   ipython-for-presentation.ipynb
#   checkpoints.ipynb
#   hsbcForeign.py
#   ipython-demo-Copy0.ipynb
# ./.ipynb_checkpoints/
#   ipython-for development-checkpoint.ipynb

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('1j_HxD4iLn8')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/1j_HxD4iLn8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=https://github.com/igaurasehrawat width=700 height=350></iframe>')
# Out:
# <iframe src=https://github.com/igauravsehrawat></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=http://en.mobile.wikipedia.org/?useformat=mobile width=700 height=350></iframe>')
# Out:
# <iframe src=http://en.mobile.wikipedia.org/?useformat=mobile width=700 height=350></iframe>

# %%
import urllib2
from lxml import etree
req_headers = {
    'User-agent':
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safar/537.36'
    }
request = urllib2.Request("https://github.com/igauravsehrawat", None, req_headers)
page = urllib2.urlopen(request).read()
parser = etree.HTMLParser()
table_root = etree.fromstring(page, parser)

# %%
from IPython.display import HTML
from base64 import b64encode
video = open("video_demo.mp4", "rb").read()
video_encoded = b64encode(video)
video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(video_encoded)
HTML(data=video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
\nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
\nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
\nabla \cdot \vec{\mathbf{B}} & = 0 
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}

# %%
from IPython.display import Math
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
